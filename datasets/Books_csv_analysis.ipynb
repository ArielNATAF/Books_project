# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
import warnings
from iso639 import languages

warnings.filterwarnings('ignore', category = FutureWarning)

# %%
path_scrapper = "D:/DocsDeCara/Boulot/IA_ML/MonGitHub/repBooksProjet/Books_project/datasets/"
file_scrapper = path_scrapper + "bothWebSites_InternetSearch_AllBooks_BookCrossing.csv"
file_scrapper_cleaned = path_scrapper + "bothWebSites_InternetSearch_AllBooks_BookCrossing_cleaned.csv"

# %%
books_scrapped = pd.read_csv(file_scrapper, sep = ';', parse_dates=['Year-Of-Publication'])
len(books_scrapped)
# Out:
# 114528

# %% [markdown]
# # First, we made a copy of data bass of scrapped books

# %%
books_scrapped_cleaned = books_scrapped.copy()

# %%
books_scrapped_cleaned.head()
# Out:
#      ISBN_10   ISBN_13             OtherID  \
# 0  195153448  9,78E+12                 0.0
# 1    2005018  9,78E+12                 0.0
# 2   60973129         0  IND:30000026059836
# 3  374157065  9,78E+12                   0
# 4  393045218  9,78E+12                 0.0
#
#                                           Book-Title           Book-Author  \
# 0                                Classical Mythology    Mark P. O. Morford
# 1                             Clara Callan : A Novel  Richard Bruce Wright
# 2                               Decision in Normandy          Carlo D'Este
# 3  Flu : The Story of the Great Influenza Pandemi...      Gina Bari Kolata
# 4                             The Mummies of Ürümchi       E. J. W. Barber
#
#   Year-Of-Publication                     Publisher        Category  \
# 0          2003-01-01  Oxford University Press, USA  Social Science
# 1          2001-01-01         HarperFlamingo Canada       Actresses
# 2          1991-01-01              Harper Perennial       1940-1949
# 3          1999-01-01                     Macmillan         Medical
# 4          1999-01-01                  W. W. Norton          Design
#
#                                          Description Language  \
# 0  Provides an introduction to classical myths pl...       en
# 1  In a small town in Canada, Clara Callan reluct...       en
# 2  Here, for the first time in paperback, is an o...       en
# 3  Describes the great flu epidemic of 1918, an o...       en
# 4  A look at the incredibly well-preserved ancien...       en
#
#                                                Image  Pages  \
# 0  http://books.google.com/books/content?id=YABYK...  808.0
# 1  http://books.google.com/books/content?id=yfx0v...  414.0
# 2  http://books.google.com/books/content?id=_LufA...  555.0
# 3  http://books.google.com/books/content?id=GkthX...  330.0
# 4  http://books.google.com/books/content?id=5OujQ...  240.0
#
#                                               Awards Author's genre Same serie
# 0                                                NaN            NaN        NaN
# 1  \nScotiabank Giller Prize (2001), Governor Gen...            NaN         []
# 2                                                NaN        History         []
# 3                                                NaN         Health         []
# 4   \nKiriyama Prize Nominee for Nonfiction (1999)\n        History         []

# %% [markdown]
# # Transformation of column names to be as our SQL data base
# Columns :
#     - 'book_id'
#     - 'average_rating'
#     - 'issue_flag'
#     - 'is_active'
#     - 'data_source'
# do not exist in books_scrapped

# %%
books_scrapped_cleaned.rename( columns = {'ISBN_10': 'isbn', 'ISBN_13': 'isbn_13', 'Book-Title': 'book_title', \
                                  'Book-Author': 'book_author', 'Year-Of-Publication': 'year_of_publication', \
                                  'Description': 'book_description', 'Language': 'book_language', \
                                  'Pages': 'number_of_pages', 'Awards': 'awards', 'Author\'s genre': 'author_genres', \
                                  'Same serie': 'books_in_series'}, inplace = True )

# %%
books_scrapped_cleaned.head()
# Out:
#         isbn   isbn_13             OtherID  \
# 0  195153448  9,78E+12                 0.0
# 1    2005018  9,78E+12                 0.0
# 2   60973129         0  IND:30000026059836
# 3  374157065  9,78E+12                   0
# 4  393045218  9,78E+12                 0.0
#
#                                           book_title           book_author  \
# 0                                Classical Mythology    Mark P. O. Morford
# 1                             Clara Callan : A Novel  Richard Bruce Wright
# 2                               Decision in Normandy          Carlo D'Este
# 3  Flu : The Story of the Great Influenza Pandemi...      Gina Bari Kolata
# 4                             The Mummies of Ürümchi       E. J. W. Barber
#
#   year_of_publication                     Publisher        Category  \
# 0          2003-01-01  Oxford University Press, USA  Social Science
# 1          2001-01-01         HarperFlamingo Canada       Actresses
# 2          1991-01-01              Harper Perennial       1940-1949
# 3          1999-01-01                     Macmillan         Medical
# 4          1999-01-01                  W. W. Norton          Design
#
#                                     book_description book_language  \
# 0  Provides an introduction to classical myths pl...            en
# 1  In a small town in Canada, Clara Callan reluct...            en
# 2  Here, for the first time in paperback, is an o...            en
# 3  Describes the great flu epidemic of 1918, an o...            en
# 4  A look at the incredibly well-preserved ancien...            en
#
#                                                Image  number_of_pages  \
# 0  http://books.google.com/books/content?id=YABYK...            808.0
# 1  http://books.google.com/books/content?id=yfx0v...            414.0
# 2  http://books.google.com/books/content?id=_LufA...            555.0
# 3  http://books.google.com/books/content?id=GkthX...            330.0
# 4  http://books.google.com/books/content?id=5OujQ...            240.0
#
#                                               awards author_genres  \
# 0                                                NaN           NaN
# 1  \nScotiabank Giller Prize (2001), Governor Gen...           NaN
# 2                                                NaN       History
# 3                                                NaN        Health
# 4   \nKiriyama Prize Nominee for Nonfiction (1999)\n       History
#
#   books_in_series
# 0             NaN
# 1              []
# 2              []
# 3              []
# 4              []

# %% [markdown]
# # Analysis of the data set
# nb lines: 114528 lines

# %%
books_scrapped_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114528 entries, 0 to 114527
# Data columns (total 15 columns):
# isbn                   114525 non-null object
# isbn_13                114525 non-null object
# OtherID                114525 non-null object
# book_title             114525 non-null object
# book_author            113582 non-null object
# year_of_publication    112308 non-null datetime64[ns]
# Publisher              97289 non-null object
# Category               103965 non-null object
# book_description       73667 non-null object
# book_language          110513 non-null object
# Image                  80665 non-null object
# number_of_pages        114525 non-null float64
# awards                 14932 non-null object
# author_genres          73607 non-null object
# books_in_series        114395 non-null object
# dtypes: datetime64[ns](1), float64(1), object(13)
# memory usage: 13.1+ MB

# %%
books_scrapped_cleaned.describe()
# Out:
#        number_of_pages
# count    114525.000000
# mean        277.309260
# std         296.112703
# min           0.000000
# 25%         176.000000
# 50%         256.000000
# 75%         359.000000
# max       80500.000000

# %% [markdown]
# ## year_of_publication

# %%
books_scrapped_cleaned["year_of_publication"].head()
# Out:
# 0   2003-01-01
# 1   2001-01-01
# 2   1991-01-01
# 3   1999-01-01
# 4   1999-01-01
# Name: year_of_publication, dtype: datetime64[ns]

# %% [markdown]
# ##### Lots of books published between 1983 and 2006

# %%
min(books_scrapped_cleaned["year_of_publication"])
# Out:
# Timestamp('1796-01-01 00:00:00')

# %%
max(books_scrapped_cleaned["year_of_publication"])
# Out:
# Timestamp('2030-01-01 00:00:00')

# %%
#cut in intervals of about 4/5 years
cut_years = pd.cut(books_scrapped_cleaned["year_of_publication"], bins=50).value_counts(sort = False)
cut_years[nb_years.values > 10]
# Out:
# (1898-12-17 11:31:12, 1903-08-23 19:40:48]       12
# (1903-08-23 19:40:48, 1908-04-28 03:50:24]       11
# (1908-04-28 03:50:24, 1913-01-01 12:00:00]       13
# (1917-09-06 20:09:36, 1922-05-13 04:19:12]       17
# (1922-05-13 04:19:12, 1927-01-16 12:28:48]       20
# (1927-01-16 12:28:48, 1931-09-21 20:38:24]       22
# (1931-09-21 20:38:24, 1936-05-27 04:48:00]       27
# (1936-05-27 04:48:00, 1941-01-30 12:57:36]       54
# (1941-01-30 12:57:36, 1945-10-05 21:07:12]       43
# (1945-10-05 21:07:12, 1950-06-11 05:16:48]      121
# (1950-06-11 05:16:48, 1955-02-14 13:26:24]      227
# (1955-02-14 13:26:24, 1959-10-20 21:36:00]      286
# (1959-10-20 21:36:00, 1964-06-25 05:45:36]      573
# (1964-06-25 05:45:36, 1969-02-28 13:55:12]      756
# (1969-02-28 13:55:12, 1973-11-03 22:04:48]     1159
# (1973-11-03 22:04:48, 1978-07-10 06:14:24]     3190
# (1978-07-10 06:14:24, 1983-03-15 14:24:00]     6649
# (1983-03-15 14:24:00, 1987-11-18 22:33:36]     9201
# (1987-11-18 22:33:36, 1992-07-24 06:43:12]    16944
# (1992-07-24 06:43:12, 1997-03-29 14:52:48]    26926
# (1997-03-29 14:52:48, 2001-12-02 23:02:24]    28971
# (2001-12-02 23:02:24, 2006-08-08 07:12:00]    16227
# (2006-08-08 07:12:00, 2011-04-13 15:21:36]      513
# (2011-04-13 15:21:36, 2015-12-17 23:31:12]      198
# (2015-12-17 23:31:12, 2020-08-22 07:40:48]      114
# (2020-08-22 07:40:48, 2025-04-27 15:50:24]       11
# Name: year_of_publication, dtype: int64

# %%
res_plot = plt.hist(books_scrapped_cleaned["year_of_publication"], bins = 50)

# %% [markdown]
# ##### Years intervals representing at least 5% of books in our dataset
# years 1978 to 2006

# %%
stats_year = pd.cut(books_scrapped_cleaned["year_of_publication"], bins=50).value_counts(sort = False, normalize = True)*100
stats_year[stats_year.values > 5]
# Out:
# (1978-07-10 06:14:24, 1983-03-15 14:24:00]     5.920326
# (1983-03-15 14:24:00, 1987-11-18 22:33:36]     8.192649
# (1987-11-18 22:33:36, 1992-07-24 06:43:12]    15.087082
# (1992-07-24 06:43:12, 1997-03-29 14:52:48]    23.975140
# (1997-03-29 14:52:48, 2001-12-02 23:02:24]    25.796025
# (2001-12-02 23:02:24, 2006-08-08 07:12:00]    14.448659
# Name: year_of_publication, dtype: float64

# %% [markdown]
# ##### Zoom on the more recent years (after 1980)

# %%
l = len(books_scrapped_cleaned.year_of_publication[books_scrapped_cleaned.year_of_publication > datetime.date(1980, 1, 1)])
p = round((l*100) / len(books_scrapped_cleaned), 2)
print("""% books published after %d (%0.2f)""" % (l, p))
# Out:
# l books published after 103793 (90.63)

# %%
res_plot = plt.hist(books_scrapped_cleaned.year_of_publication[np.logical_and( \
                                                            books_scrapped_cleaned.year_of_publication > datetime.date(1980, 1, 1), \
                                                            books_scrapped_cleaned.year_of_publication < datetime.date(2005, 1, 1))], \
             bins = 25)

# %% [markdown]
# ## Category

# %% [markdown]
# ##### lots of books categories : 5 010 !

# %%
books_scrapped_cleaned["Category"].value_counts(sort = False)
# Out:
# Palos Verdes Peninsula (Calif.)                     1
# Sri Lanka                                           3
# Calendars                                           1
# Information resources management                    1
# Carcharocles megalodon                              1
# Crusades                                            4
# Psychological tests                                 1
# Cichlids                                            1
# Hermetism                                           1
# Materia medica, Vegetable                           1
# Retirement                                          1
# Marblehead (Mass.)                                  1
# Authors and publishers.                             1
# AMERICAN BOOK AWARD.                                1
# Kindergarten                                        2
# Authors, Brazilian                                  2
# Nottingham                                          1
# Serial murders                                      4
# Home-based businesses                               4
# Project management                                  1
# Women costume designers                             1
# African American families                           7
# Communication                                       9
# Hamsters as pets                                    1
# Prisoners of war in literature                      1
# Bumppo, Natty (Fictitious character)                1
# Occupations                                         3
# Relationships                                       7
# Coca                                                1
# Athletes                                            2
#                                                    ..
# Buffy the Vampire Slayer (Fictitious character)     3
# Suspense fiction                                    3
# Electronic circuits                                 2
# Drew, Nancy (Fictitious character)                  1
# Naps (Sleep)                                        1
# Cross-country skiing                                1
# Authors, Irish                                      2
# Jogging.                                            1
# Christian youth                                     1
# Leadership                                         12
# Bullies                                             9
# Stunt performers                                    1
# Indians of South America                            1
# Success.                                            2
# Prisoners of war                                    2
# Imaginary interviews                                1
# Cities and towns                                   11
# Crime and criminals                                 7
# AWK (Langage de programmation)                      1
# Antiques                                           10
# Beverly Hills 90210 (Television program).           1
# Agricultural laborers                               1
# Computer technicians                                1
# New business enterprises                            5
# Dressmaking                                         1
# Enterprise (Imaginary space vehicle)                1
# London Bridge (London, England)                     1
# Sculptors                                           1
# Women teachers                                      1
# Millionaires                                        3
# Name: Category, Length: 5010, dtype: int64

# %%
#When considering categories, which is the one with 
#           the least books insied ?
#           the most books inside ?
stats_cat = books_scrapped_cleaned["Category"].value_counts(sort = False)
print("min nb: %d / max nb: %d" % (min(stats_cat.values), max(stats_cat.values)))
# Out:
# min nb: 1 / max nb: 40402

# %% [markdown]
# ##### Lots of Fiction : 35.28 % of all books

# %%
stats_cat.index[np.argmax(stats_cat.values)]
# Out:
# 'Fiction'

# %%
#pourcentage of Fiction books in our dataset
round((max(stats_cat.values) / len(books_scrapped_cleaned) ) * 100, 2)
# Out:
# 35.28

# %% [markdown]
# ##### Number of categories with only one book inside 3005 !
# Saved in cat_one_book.csv file

# %%
cat_one_book = stats_cat[stats_cat.values == 1]
cat_one_book
# Out:
# Palos Verdes Peninsula (Calif.)                                             1
# Calendars                                                                   1
# Information resources management                                            1
# Carcharocles megalodon                                                      1
# Psychological tests                                                         1
# Cichlids                                                                    1
# Hermetism                                                                   1
# Materia medica, Vegetable                                                   1
# Retirement                                                                  1
# Marblehead (Mass.)                                                          1
# Authors and publishers.                                                     1
# AMERICAN BOOK AWARD.                                                        1
# Nottingham                                                                  1
# Project management                                                          1
# Women costume designers                                                     1
# Hamsters as pets                                                            1
# Prisoners of war in literature                                              1
# Bumppo, Natty (Fictitious character)                                        1
# Coca                                                                        1
# Exorcism                                                                    1
# Toth, Lazlo (Fictitious character)                                          1
# Accelerated Reader, Disk C016                                               1
# Local transit                                                               1
# Ethnologie                                                                  1
# Philologists                                                                1
# African languages                                                           1
# Chipmunks                                                                   1
# Mineralogy                                                                  1
# Mithgar (Imaginary place)                                                   1
# Satire, English                                                             1
#                                                                            ..
# Gypsies                                                                     1
# Pro-choice movement                                                         1
# Mišljenje - Spremembe - Reševanje problemov - Osebnost - Uspeh - Študije    1
# Short stories, Spanish                                                      1
# Goddess religion                                                            1
# Academic freedom                                                            1
# PSYCHOLOGY                                                                  1
# Electronic toys                                                             1
# Church work with youth                                                      1
# Cantar de mío Cid                                                           1
# Electromyography                                                            1
# Financial institutions                                                      1
# Knots and splices                                                           1
# Drew, Nancy (Fictitious character)                                          1
# Naps (Sleep)                                                                1
# Cross-country skiing                                                        1
# Jogging.                                                                    1
# Christian youth                                                             1
# Stunt performers                                                            1
# Indians of South America                                                    1
# Imaginary interviews                                                        1
# AWK (Langage de programmation)                                              1
# Beverly Hills 90210 (Television program).                                   1
# Agricultural laborers                                                       1
# Computer technicians                                                        1
# Dressmaking                                                                 1
# Enterprise (Imaginary space vehicle)                                        1
# London Bridge (London, England)                                             1
# Sculptors                                                                   1
# Women teachers                                                              1
# Name: Category, Length: 3005, dtype: int64

# %%
pd.DataFrame(cat_one_book.index[:]).to_csv(path_scrapper + "cat_one_book.csv", index = False)

# %% [markdown]
# ##### Categories the most represented

# %%
stats_cat.sort_values(ascending = False)
# Out:
# Fiction                                                                  40402
# Juvenile Fiction                                                          5893
# Biography & Autobiography                                                 3072
# Mystery                                                                   2894
# History                                                                   1994
# Religion                                                                  1741
# Romance                                                                   1361
# Fantasy                                                                   1350
# Humor                                                                     1281
# Juvenile Nonfiction                                                       1248
# Classics                                                                  1163
# Nonfiction                                                                1103
# Social Science                                                            1095
# Business & Economics                                                       983
# Science Fiction                                                            981
# Body, Mind & Spirit                                                        905
# Family & Relationships                                                     880
# Historical                                                                 854
# Health & Fitness                                                           843
# Cooking                                                                    744
# Psychology                                                                 730
# Travel                                                                     718
# Poetry                                                                     686
# Self-Help                                                                  677
# Science                                                                    669
# Childrens                                                                  627
# Horror                                                                     580
# Reference                                                                  566
# Philosophy                                                                 516
# Computers                                                                  480
#                                                                          ...
# Paganism                                                                     1
# Histoires erotiques                                                          1
# Cookery, British                                                             1
# Indian captivities                                                           1
# Horror in mass media                                                         1
# Aged woman                                                                   1
# Animal sanctuaries                                                           1
# Saskatchewan                                                                 1
# Wien - Wissenschaftler - Charakterkunde - Belletristische Darstellung        1
# Hostage negotiations                                                         1
# Children's reference books                                                   1
# Social work administration.                                                  1
# Sociologie - Dictionnaires anglais                                           1
# Bullfighters                                                                 1
# Belgium                                                                      1
# Cole, Lewis (Fictitious character)                                           1
# Taiwan                                                                       1
# Literature, 1850- - Encyclopaedias                                           1
# Auckland (N.Z.)                                                              1
# Grapes of Wrath                                                              1
# Quantum leap (Television program)                                            1
# Davis family (Fictitious characters : Oke)                                   1
# Cooking (Vegetables)                                                         1
# African American baseball players                                            1
# Foucault's pendulum                                                          1
# Carbohydrates, Refined                                                       1
# Horror tales.                                                                1
# Czech Republic                                                               1
# Novela francesa-                                                             1
# Palos Verdes Peninsula (Calif.)                                              1
# Name: Category, Length: 5010, dtype: int64

# %%
res_plot = plt.hist(stats_cat[np.logical_and(stats_cat.values < 6000, stats_cat.values >1)].values)

# %% [markdown]
# ##### Repartition of the number of elements insed categories : lots of categories with less than 80 books inside

# %%
nb_elt_cat = pd.cut(stats_cat.values, bins=500).value_counts()
nb_elt_cat[nb_elt_cat.values > 0].sort_values(ascending = False)
# Out:
# (-39.401, 81.802]       4924
# (81.802, 162.604]         28
# (162.604, 243.406]         9
# (243.406, 324.208]         9
# (324.208, 405.01]          7
# (405.01, 485.812]          4
# (647.416, 728.218]         4
# (809.02, 889.822]          3
# (566.614, 647.416]         2
# (1293.832, 1374.634]       2
# (1213.03, 1293.832]        2
# (1051.426, 1132.228]       2
# (970.624, 1051.426]        2
# (485.812, 566.614]         2
# (728.218, 809.02]          2
# (40321.198, 40402.0]       1
# (5818.744, 5899.546]       1
# (1132.228, 1213.03]        1
# (1697.842, 1778.644]       1
# (1940.248, 2021.05]        1
# (2829.07, 2909.872]        1
# (3071.476, 3152.278]       1
# (889.822, 970.624]         1
# dtype: int64

# %% [markdown]
# res_plot = plt.hist(stats_cat[np.logical_and(stats_cat.values < 81, stats_cat.values >1)].values)

# %% [markdown]
# ##### To keep 95% of the most important categories, we could keep the 3989 first categories (on 5010)

# %%
#most represented author gender first
stats_cat_sorted = stats_cat.sort_values(ascending = False)
print("nb of categories:", len(stats_cat_sorted))

cumstats = np.cumsum(stats_cat_sorted.values)
cumstats = cumstats / cumstats[len(cumstats)-1]
type(cumstats)
len(cumstats[cumstats > 0.95])
# Out:
# nb of categories: 5010
# 3989

# %% [markdown]
# ##### Categories representing at least 1% of all the books

# %%
stats_cat[(stats_cat.values/len(books_scrapped_cleaned["Category"]))*100 > 1]
# Out:
# Mystery                       2894
# Juvenile Fiction              5893
# Humor                         1281
# Romance                       1361
# History                       1994
# Religion                      1741
# Biography & Autobiography     3072
# Classics                      1163
# Fantasy                       1350
# Fiction                      40402
# Juvenile Nonfiction           1248
# Name: Category, dtype: int64

# %% [markdown]
# ## Authors
# Scrapper action results in only one author name inside "book_author" column

# %% [markdown]
# ## Authors gender
# Several genders can appear in this column, with a & as separator

# %%
books_scrapped_cleaned["author_genres"].head(10)
# Out:
# 0                     NaN
# 1                     NaN
# 2                 History
# 3                  Health
# 4                 History
# 5    Literature & Fiction
# 6                 History
# 7     Mystery & Thrillers
# 8                 History
# 9    Literature & Fiction
# Name: author_genres, dtype: object

# %% [markdown]
# ##### Creation of a second column for the second author gender
# Done in parallel on Colab, because it takes too much time on my PC !

# %%
books_scrapped_cleaned = pd.read_csv(file_scrapper_cleaned, sep = '|')

# %% [markdown]
# ##### Analysis of author_genres

# %%
stats_aut = books_scrapped_cleaned["author_genres"].value_counts(sort = False)
stats_aut
# Out:
# Folk Tales                        21
# Relationships                     29
# Cats                               2
# Film                              18
# Women's Fiction                   15
# Geology                            1
# Editor                             1
# Women                             72
# Computing                          2
# Contemporary                     206
# Horticulture                       2
# Short Story                        1
# Paranormal                        85
# Computer Science                   1
# Chronicles                         1
# Film Critic                        1
# Firearms                           1
# Erotic                             3
# Mystery                         9505
# Young Adult Paranormal             2
# Aging                              1
# Home                              59
# Comedy                             7
# Adventure                         51
# Play                               1
# Magic Realism                      3
# Illustrations                      2
# Literary Philosophy                1
# Anthologies                        4
# Business                         308
#                                 ...
# Policing                           2
# Scottish Literature                1
# Historical Fiction              1825
# Manx History                       1
# Social Realism                     1
# Egyptology                         1
# Sheet Music                        1
# Language                           7
# Geography                          2
# Paleontology                       1
# Novel                              2
# History and Military History       3
# Cartooning                         2
# Christian Fiction                  9
# Upmarket Women's Fiction           1
# Current Events                     1
# Selfhelp                           3
# Music Journalism                   1
# Fiction                         5757
# Theatre                          455
# Dietology                          1
# Manga                            116
# Art History                        2
# Political Theorist                 1
# Various Author                    10
# Neuroscience                       2
# Calligraphy                        1
# Ufology                            5
# Celtic Studies                     1
# Historical People                  2
# Name: author_genres, Length: 338, dtype: int64

# %%
print("min nb: %d / max nb: %d" % (min(stats_aut.values), max(stats_aut.values)))
# Out:
# min nb: 1 / max nb: 11880

# %%
stats_aut.index[np.argmax(stats_aut.values)]
# Out:
# 'Literature'

# %% [markdown]
# ##### Lots of Literature as author gender

# %%
stats_aut_sorted = stats_aut.sort_values(ascending = False)
stats_aut_sorted[stats_aut_sorted.values > 100]
# Out:
# Literature            11880
# Mystery                9505
# Romance                8118
# Science Fiction        6972
# Fiction                5757
# Children's Books       4825
# Nonfiction             3088
# Children's             1834
# Historical Fiction     1825
# Horror                 1682
# Biographies            1312
# History                1257
# Religion               1240
# Poetry                 1177
# Fantasy                 983
# Young Adult             881
# Thriller                783
# Comics                  772
# Science                 610
# Philosophy              590
# Crime                   549
# Theatre                 455
# Health                  407
# Travel                  400
# Memoir                  373
# Biography               347
# Humor                   340
# Business                308
# Christian               297
# Politics                275
# Spirituality            236
# Psychology              228
# Contemporary            206
# Suspense                200
# Cooking                 190
# Outdoors                167
# Short Stories           149
# Art                     142
# Humor and Comedy        140
# Arts                    133
# Parenting               132
# Self Help               130
# Manga                   116
# Sports                  116
# Name: author_genres, dtype: int64

# %% [markdown]
# ##### Number of element inside each author genres, when 1 < nb_elt < 9000

# %%
res_plot = plt.hist(stats_aut[np.logical_and(stats_aut.values < 9000, stats_aut.values >1)].values)

# %%
stats_aut_sorted = stats_aut.sort_values(ascending = True)
res_plot = plt.hist(stats_aut_sorted.values, density = True, cumulative = True)

# %% [markdown]
# ##### To keep 95% of the most important author genres, we could keep the 303 first author genres (on 338)

# %%
#most represented author gender first
stats_aut_sorted = stats_aut.sort_values(ascending = False)
print("nb of genders:", len(stats_aut_sorted))

cumstats = np.cumsum(stats_aut_sorted.values)
cumstats = cumstats / cumstats[len(cumstats)-1]
type(cumstats)
len(cumstats[cumstats > 0.95])
# Out:
# nb of genders: 338
# 303

# %% [markdown]
# ##### Number of element inside each author genres, classified by intervals
# Lots of author genres with less than 240 elements inside

# %%
nb_elt_aut = pd.cut(stats_aut.values, bins=50).value_counts()
nb_elt_aut[nb_elt_aut.values > 0].sort_values(ascending = False)
# Out:
# (-10.879, 238.58]      308
# (238.58, 476.16]         9
# (1664.06, 1901.64]       3
# (1188.9, 1426.48]        3
# (713.74, 951.32]         3
# (476.16, 713.74]         3
# (951.32, 1188.9]         2
# (11642.42, 11880.0]      1
# (9504.2, 9741.78]        1
# (8078.72, 8316.3]        1
# (6890.82, 7128.4]        1
# (5702.92, 5940.5]        1
# (4752.6, 4990.18]        1
# (2851.96, 3089.54]       1
# dtype: int64

# %% [markdown]
# ##### author genres representing at least 1% of all the books

# %%
stats_aut[(stats_aut.values/len(books_scrapped_cleaned["author_genres"]))*100 > 1]
# Out:
# Mystery                9505
# Poetry                 1177
# Science Fiction        6972
# Children's Books       4825
# Romance                8118
# History                1257
# Religion               1240
# Biographies            1312
# Children's             1834
# Nonfiction             3088
# Literature            11880
# Horror                 1682
# Historical Fiction     1825
# Fiction                5757
# Name: author_genres, dtype: int64

# %% [markdown]
# ##### author genres with only one element inside

# %%
aut_one_book = stats_aut[stats_aut.values == 1]
aut_one_book
# Out:
# Geology                       1
# Editor                        1
# Short Story                   1
# Computer Science              1
# Chronicles                    1
# Film Critic                   1
# Firearms                      1
# Aging                         1
# Play                          1
# Literary Philosophy           1
# Native Americans              1
# Gothic                        1
# Experimental                  1
# Scots Language                1
# Urban Legends                 1
# Cartoonist                    1
# Emergency                     1
# Essayist                      1
# Real Estate                   1
# War Fiction                   1
# Civil Rights                  1
# Contemporary Non Fiction      1
# Games                         1
# Numismatics                   1
# Radio Dramas                  1
# Middle Grade                  1
# Attention Deficit Disorder    1
# Fiction/magic Realism         1
# Family Drama                  1
# Medieval History              1
#                              ..
# Translation                   1
# Chivalric Romance             1
# Caricature                    1
# Shipping                      1
# Psychoanalyst                 1
# Literary Fantasy              1
# Politcs                       1
# Animals                       1
# Programming                   1
# Gothic Fiction                1
# Forensics                     1
# Narrativa                     1
# Scottish Culture              1
# Mysteries                     1
# Free Software                 1
# Buddhism                      1
# World War II                  1
# Scottish Literature           1
# Manx History                  1
# Social Realism                1
# Egyptology                    1
# Sheet Music                   1
# Paleontology                  1
# Upmarket Women's Fiction      1
# Current Events                1
# Music Journalism              1
# Dietology                     1
# Political Theorist            1
# Calligraphy                   1
# Celtic Studies                1
# Name: author_genres, Length: 116, dtype: int64

# %%
pd.DataFrame(aut_one_book.index[:]).to_csv(path_scrapper + "author_gender_one_book.csv", index = False)

# %% [markdown]
# ##### Analysis of author_genres_other

# %%
stats_aut_other = books_scrapped_cleaned["author_genres_other"].value_counts(sort = False)
stats_aut_other
# Out:
# Film                        4
# Painting                    3
# Tv                          1
# Internet                   29
# Memoir                      1
# Crafts                      1
# Gender Studies             72
# Graphic Novels            608
# Science Fiction           131
# Suspense                    4
# History                     3
# Television                  3
# Sexuality                   2
# Lesbian                    79
# Memoirs                  1312
# Thrillers                7522
# Investing                 166
# Military History            1
# Drama                       1
# Garden                     59
# Hobbies                    69
# Management                  5
# Social Sciences             3
# Nature                    167
# Nonfiction                  9
# Literature                  1
# Contemporary Fiction       12
# Biography                   2
# Humour                      1
# Technical                  30
# Fantasy                  5545
# Culture                     1
# Photography               130
# Spirituality              956
# Sociology                   1
# Legends                    10
# Families                  132
# Supernatural                4
# Fiction                 11854
# Name: author_genres_other, dtype: int64

# %%
print("min nb: %d / max nb: %d" % (min(stats_aut_other.values), max(stats_aut_other.values)))
# Out:
# min nb: 1 / max nb: 11854

# %% [markdown]
# ##### Lots of Fiction as author other gender

# %%
stats_aut_other.index[np.argmax(stats_aut_other.values)]
# Out:
# 'Fiction'

# %%
stats_aut_other_sorted = stats_aut_other.sort_values(ascending = False)
stats_aut_other_sorted[stats_aut_other_sorted.values > 100]
# Out:
# Fiction            11854
# Thrillers           7522
# Fantasy             5545
# Memoirs             1312
# Spirituality         956
# Graphic Novels       608
# Nature               167
# Investing            166
# Families             132
# Science Fiction      131
# Photography          130
# Name: author_genres_other, dtype: int64

# %% [markdown]
# ##### Number of element inside each author other genres, when 1 < nb_elt < 8000

# %%
res_plot = plt.hist(stats_aut_other[np.logical_and(stats_aut_other.values < 8000, stats_aut_other.values >1)].values)

# %%
stats_aut_other_sorted = stats_aut_other.sort_values(ascending = True)
res_plot = plt.hist(stats_aut_other_sorted.values, density = True, cumulative = True)

# %% [markdown]
# ##### To keep 95% of the most important author other genres, we could keep the 34 first author other genres (on 39)

# %%
#most represented author gender first
stats_aut_other_sorted = stats_aut_other.sort_values(ascending = False)
print("nb of genders:", len(stats_aut_other_sorted))

cumstats = np.cumsum(stats_aut_other_sorted.values)
cumstats = cumstats / cumstats[len(cumstats)-1]
type(cumstats)
len(cumstats[cumstats > 0.95])
# Out:
# nb of genders: 39
# 34

# %% [markdown]
# ##### Number of element inside each author genres, classified by intervals
# Lots of author genres with less than 120 elements inside

# %%
nb_elt_aut_other = pd.cut(stats_aut_other.values, bins=100).value_counts()
nb_elt_aut_other[nb_elt_aut_other.values > 0].sort_values(ascending = False)
# Out:
# (-10.853, 119.53]      28
# (119.53, 238.06]        5
# (11735.47, 11854.0]     1
# (7468.39, 7586.92]      1
# (5453.38, 5571.91]      1
# (1304.83, 1423.36]      1
# (949.24, 1067.77]       1
# (593.65, 712.18]        1
# dtype: int64

# %% [markdown]
# ##### author other genres with only one element inside

# %%
aut_other_one_book = stats_aut_other[stats_aut_other.values == 1]
aut_other_one_book
# Out:
# Tv                  1
# Memoir              1
# Crafts              1
# Military History    1
# Drama               1
# Literature          1
# Humour              1
# Culture             1
# Sociology           1
# Name: author_genres_other, dtype: int64

# %%
pd.DataFrame(aut_other_one_book.index[:]).to_csv(path_scrapper + "author_other_gender_one_book.csv", index = False)

# %% [markdown]
# ##### author other genres representing at least 1% of all the books

# %%
stats_aut_other[(stats_aut_other.values/len(books_scrapped_cleaned["author_genres_other"]))*100 > 1]
# Out:
# Memoirs       1312
# Thrillers     7522
# Fantasy       5545
# Fiction      11854
# Name: author_genres_other, dtype: int64

# %% [markdown]
# ##### Both author genres columns analysis

# %%
other_genres = stats_aut_other.index.unique()
genres = stats_aut.index.unique()

# %%
genres_tab = stats_aut
print(genres_tab)

for g in other_genres:
    if g in genres:
        genres_tab[g] = stats_aut_other[g] + stats_aut[g]
    else:
        genres_tab[g] = stats_aut_other[g]
# Out:
# Folk Tales                        21
# Relationships                     29
# Cats                               2
# Film                              18
# Women's Fiction                   15
# Geology                            1
# Editor                             1
# Women                             72
# Computing                          2
# Contemporary                     206
# Horticulture                       2
# Short Story                        1
# Paranormal                        85
# Computer Science                   1
# Chronicles                         1
# Film Critic                        1
# Firearms                           1
# Erotic                             3
# Mystery                         9505
# Young Adult Paranormal             2
# Aging                              1
# Home                              59
# Comedy                             7
# Adventure                         51
# Play                               1
# Magic Realism                      3
# Illustrations                      2
# Literary Philosophy                1
# Anthologies                        4
# Business                         308
#                                 ...
# Policing                           2
# Scottish Literature                1
# Historical Fiction              1825
# Manx History                       1
# Social Realism                     1
# Egyptology                         1
# Sheet Music                        1
# Language                           7
# Geography                          2
# Paleontology                       1
# Novel                              2
# History and Military History       3
# Cartooning                         2
# Christian Fiction                  9
# Upmarket Women's Fiction           1
# Current Events                     1
# Selfhelp                           3
# Music Journalism                   1
# Fiction                         5757
# Theatre                          455
# Dietology                          1
# Manga                            116
# Art History                        2
# Political Theorist                 1
# Various Author                    10
# Neuroscience                       2
# Calligraphy                        1
# Ufology                            5
# Celtic Studies                     1
# Historical People                  2
# Name: author_genres, Length: 338, dtype: int64

# %%
genres_tab
# Out:
# Folk Tales                     21
# Relationships                  29
# Cats                            2
# Film                           58
# Women's Fiction                15
# Geology                         1
# Editor                          1
# Women                          72
# Computing                       2
# Contemporary                  206
# Horticulture                    2
# Short Story                     1
# Paranormal                     85
# Computer Science                1
# Chronicles                      1
# Film Critic                     1
# Firearms                        1
# Erotic                          3
# Mystery                      9505
# Young Adult Paranormal          2
# Aging                           1
# Home                           59
# Comedy                          7
# Adventure                      51
# Play                            1
# Magic Realism                   3
# Illustrations                   2
# Literary Philosophy             1
# Anthologies                     4
# Business                      308
#                             ...
# Upmarket Women's Fiction        1
# Current Events                  1
# Selfhelp                        3
# Music Journalism                1
# Fiction                     29125
# Theatre                       455
# Dietology                       1
# Manga                         116
# Art History                     2
# Political Theorist              1
# Various Author                 10
# Neuroscience                    2
# Calligraphy                     1
# Ufology                         5
# Celtic Studies                  1
# Historical People               2
# Painting                        3
# Tv                              1
# Internet                       29
# Television                      3
# Sexuality                       2
# Memoirs                      1312
# Garden                         59
# Hobbies                        69
# Contemporary Fiction           12
# Technical                      30
# Culture                         1
# Legends                        10
# Families                      132
# Supernatural                    4
# Name: author_genres, Length: 352, dtype: int64

# %% [markdown]
# ##### Lots of Literature as unified author genres

# %%
genres_tab_sorted = genres_tab.sort_values(ascending = False)
genres_tab_sorted[genres_tab_sorted > 100]
# Out:
# Literature            35641
# Fiction               29125
# Science Fiction       21047
# Mystery                9505
# Nonfiction             9273
# Fantasy                8494
# Romance                8118
# Thrillers              7576
# Children's Books       4825
# History                3774
# Children's             1834
# Historical Fiction     1825
# Horror                 1682
# Spirituality           1664
# Memoirs                1312
# Biographies            1312
# Religion               1240
# Poetry                 1177
# Memoir                 1120
# Biography              1043
# Young Adult             881
# Thriller                783
# Comics                  772
# Graphic Novels          626
# Science                 610
# Suspense                604
# Philosophy              590
# Crime                   549
# Theatre                 455
# Health                  407
# Travel                  400
# Humor                   340
# Business                308
# Christian               297
# Social Sciences         282
# Politics                275
# Psychology              228
# Crafts                  208
# Contemporary            206
# Nature                  197
# Cooking                 190
# Investing               181
# Outdoors                167
# Photography             151
# Short Stories           149
# Art                     142
# Humor and Comedy        140
# Arts                    133
# Parenting               132
# Families                132
# Self Help               130
# Manga                   116
# Sports                  116
# Name: author_genres, dtype: int64

# %% [markdown]
# ##### To keep 95% of the most important unified author genres, we could keep the 324 first author other genres (on 352)

# %%
#most represented author gender first
genres_tab_sorted = genres_tab.sort_values(ascending = False)
print("nb of genders:", len(genres_tab_sorted))

cumstats = np.cumsum(genres_tab_sorted.values)
cumstats = cumstats / cumstats[len(cumstats)-1]
type(cumstats)
len(cumstats[cumstats > 0.95])
# Out:
# nb of genders: 352
# 324

# %% [markdown]
# ##### Repartition of the number of elements insed unified author genres : lots of author genres with less than 180 books inside

# %%
nb_elt_aut = pd.cut(genres_tab.values, bins=200).value_counts()
nb_elt_aut[nb_elt_aut.values > 0].sort_values(ascending = False)
# Out:
# (-34.64, 179.2]       310
# (179.2, 357.4]         11
# (535.6, 713.8]          5
# (357.4, 535.6]          3
# (713.8, 892.0]          3
# (1070.2, 1248.4]        3
# (1604.8, 1783.0]        2
# (1248.4, 1426.6]        2
# (1783.0, 1961.2]        2
# (3743.2, 3921.4]        1
# (29047.6, 29225.8]      1
# (4812.4, 4990.6]        1
# (7485.4, 7663.6]        1
# (8020.0, 8198.2]        1
# (892.0, 1070.2]         1
# (8376.4, 8554.6]        1
# (9267.4, 9445.6]        1
# (9445.6, 9623.8]        1
# (21028.6, 21206.8]      1
# (35462.8, 35641.0]      1
# dtype: int64

# %% [markdown]
# ##### unified author genres representing at least 1% of all the books

# %%
genres_tab[(genres_tab.values/len(books_scrapped_cleaned["author_genres_other"]))*100 > 1]
# Out:
# Mystery                9505
# Poetry                 1177
# Science Fiction       21047
# Children's Books       4825
# Romance                8118
# History                3774
# Thrillers              7576
# Religion               1240
# Biographies            1312
# Children's             1834
# Nonfiction             9273
# Literature            35641
# Fantasy                8494
# Spirituality           1664
# Horror                 1682
# Historical Fiction     1825
# Fiction               29125
# Memoirs                1312
# Name: author_genres, dtype: int64

# %% [markdown]
# ##### unified author genres with only 1 unified author genres inside

# %%
aut_genres_tab_one = genres_tab[genres_tab.values == 1]
aut_genres_tab_one
# Out:
# Geology                       1
# Editor                        1
# Short Story                   1
# Computer Science              1
# Chronicles                    1
# Film Critic                   1
# Firearms                      1
# Aging                         1
# Play                          1
# Literary Philosophy           1
# Native Americans              1
# Gothic                        1
# Experimental                  1
# Scots Language                1
# Urban Legends                 1
# Cartoonist                    1
# Emergency                     1
# Essayist                      1
# Real Estate                   1
# War Fiction                   1
# Civil Rights                  1
# Contemporary Non Fiction      1
# Games                         1
# Numismatics                   1
# Radio Dramas                  1
# Middle Grade                  1
# Attention Deficit Disorder    1
# Fiction/magic Realism         1
# Family Drama                  1
# Medieval History              1
#                              ..
# Caricature                    1
# Shipping                      1
# Psychoanalyst                 1
# Literary Fantasy              1
# Politcs                       1
# Animals                       1
# Programming                   1
# Gothic Fiction                1
# Forensics                     1
# Narrativa                     1
# Scottish Culture              1
# Mysteries                     1
# Free Software                 1
# Buddhism                      1
# World War II                  1
# Scottish Literature           1
# Manx History                  1
# Social Realism                1
# Egyptology                    1
# Sheet Music                   1
# Paleontology                  1
# Upmarket Women's Fiction      1
# Current Events                1
# Music Journalism              1
# Dietology                     1
# Political Theorist            1
# Calligraphy                   1
# Celtic Studies                1
# Tv                            1
# Culture                       1
# Name: author_genres, Length: 118, dtype: int64

# %%
pd.DataFrame(aut_genres_tab_one.index[:]).to_csv(path_scrapper + "author_unified_gender_one_book.csv", index = False)

# %% [markdown]
# ## book_language

# %% [markdown]
# ##### Different codings for the same language !

# %%
books_scrapped_cleaned = pd.read_csv(file_scrapper_cleaned, sep = '|')

# %%
books_scrapped_cleaned["book_language"].value_counts()
# Out:
# en                             101060
# un                               2389
# de                               1506
# German                           1418
# es                               1028
# French                            932
# fr                                810
# Spanish                           669
# it                                275
# Italian                            88
# nl                                 70
# ca                                 54
# pt                                 43
# da                                 30
# Catalan; Valencian                 22
# Dutch                              22
# pl                                 15
# Portuguese                         14
# Finnish                             5
# Multiple languages                  4
# Swedish                             4
# gl                                  3
# ru                                  3
# Romanian                            3
# sv                                  3
# Hungarian                           3
# ms                                  3
# ko                                  3
# Polish                              2
# el                                  2
# cs                                  2
# sk                                  2
# la                                  2
# Korean                              2
# Latvian                             1
# no                                  1
# ar                                  1
# sr                                  1
# ga                                  1
# sw                                  1
# ja                                  1
# ro                                  1
# Scots                               1
# Croatian                            1
# English, Middle (1100-1500)         1
# eu                                  1
# hr                                  1
# Danish                              1
# fi                                  1
# Russian                             1
# sl                                  1
# Persian                             1
# Latin                               1
# zh-CN                               1
# Chinese                             1
# zh-TW                               1
# Name: book_language, dtype: int64

# %%
languages.get(name = "German").alpha2
# Out:
# 'de'

# %% [markdown]
# #### First I transform languages coded with several words

# %%
languages.get(name = "Catalan; Valencian").alpha2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-4e9adc6edb88> in <module>
# ----> 1 languages.get(name = "Catalan; Valencian").alpha2
#
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\iso639\iso639.py in get(self, **kwargs)
#     263             raise AttributeError('Only one keyword expected')
#     264         key, value = kwargs.popitem()
# --> 265         return getattr(self, key)[value]
#
# KeyError: 'Catalan; Valencian'

# %%
books_scrapped_cleaned.book_language[books_scrapped_cleaned.book_language == "Catalan; Valencian"] = "ca"
# Out:
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
books_scrapped_cleaned["book_language"].value_counts()
# Out:
# en                             101060
# un                               2389
# de                               1506
# German                           1418
# es                               1028
# French                            932
# fr                                810
# Spanish                           669
# it                                275
# Italian                            88
# ca                                 76
# nl                                 70
# pt                                 43
# da                                 30
# Dutch                              22
# pl                                 15
# Portuguese                         14
# Finnish                             5
# Swedish                             4
# Multiple languages                  4
# gl                                  3
# ru                                  3
# Romanian                            3
# sv                                  3
# Hungarian                           3
# ms                                  3
# ko                                  3
# Polish                              2
# el                                  2
# cs                                  2
# sk                                  2
# la                                  2
# Korean                              2
# Latvian                             1
# no                                  1
# ar                                  1
# sr                                  1
# ga                                  1
# sw                                  1
# ja                                  1
# ro                                  1
# Scots                               1
# Croatian                            1
# English, Middle (1100-1500)         1
# eu                                  1
# hr                                  1
# Danish                              1
# fi                                  1
# Russian                             1
# sl                                  1
# Persian                             1
# Latin                               1
# zh-CN                               1
# Chinese                             1
# zh-TW                               1
# Name: book_language, dtype: int64

# %%
languages.get(name = "English, Middle (1100-1500)").alpha2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-a3efab79eb23> in <module>
# ----> 1 languages.get(name = "English, Middle (1100-1500)").alpha2
#
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\iso639\iso639.py in get(self, **kwargs)
#     263             raise AttributeError('Only one keyword expected')
#     264         key, value = kwargs.popitem()
# --> 265         return getattr(self, key)[value]
#
# KeyError: 'English, Middle (1100-1500)'

# %%
books_scrapped_cleaned.book_language[books_scrapped_cleaned.book_language == "English, Middle (1100-1500)"] = "en"
# Out:
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
books_scrapped_cleaned.book_language[books_scrapped_cleaned.book_language == "Multiple languages"] = "en"
# Out:
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
books_scrapped_cleaned.book_language[books_scrapped_cleaned.book_language == "zh-CN"] = "zh"
# Out:
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
books_scrapped_cleaned.book_language[books_scrapped_cleaned.book_language == "zh-TW"] = "zh"
# Out:
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
books_scrapped_cleaned["book_language"].value_counts()
# Out:
# en            101065
# de              2501
# un              2389
# es              1497
# fr              1475
# German           423
# it               334
# French           267
# Spanish          200
# nl                81
# ca                76
# pt                51
# da                30
# Italian           29
# pl                17
# Dutch             11
# fi                 6
# Portuguese         6
# sv                 5
# ko                 4
# ru                 4
# ro                 3
# gl                 3
# la                 3
# zh                 3
# ms                 3
# hr                 2
# sk                 2
# Swedish            2
# cs                 2
# el                 2
# hu                 2
# Korean             1
# sw                 1
# ja                 1
# eu                 1
# Romanian           1
# ga                 1
# Scots              1
# sr                 1
# Danish             1
# sl                 1
# no                 1
# Latvian            1
# Hungarian          1
# fa                 1
# ar                 1
# Name: book_language, dtype: int64

# %% [markdown]
# ##### Then transformation of names in alpha2 coding (for example "German" in "de")

# %%
german_test = books_scrapped_cleaned["book_language"][34]
print("%s %s" %(german_test, len(german_test)))
# Out:
# German 6

# %%
lines_to_transf = books_scrapped_cleaned.book_language[books_scrapped_cleaned.book_language.str.len() > 2]
lines_to_transf.head()
# Out:
# 79515    German
# 79528     Dutch
# 79529     Dutch
# 79536    German
# 79564    German
# Name: book_language, dtype: object

# %%
for i in lines_to_transf.index:
    books_scrapped_cleaned.book_language[i] = languages.get(name = books_scrapped_cleaned.book_language[i]).alpha2
# Out:
# D:\DocsDeCara\Boulot\Programmation\Python\RepertoireAnaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ##### Mainly english books

# %%
books_scrapped_cleaned["book_language"].value_counts()
# Out:
# en    101065
# de      2924
# un      2389
# fr      1742
# es      1697
# it       363
# nl        92
# ca        76
# pt        57
# da        31
# pl        17
# sv         7
# fi         6
# ko         5
# ru         4
# ro         4
# zh         3
# hu         3
# ms         3
# gl         3
# la         3
# cs         2
# sk         2
# el         2
# hr         2
# ar         1
# ga         1
# sw         1
# ja         1
# sr         1
# lv         1
# no         1
# fa         1
# eu         1
# sl         1
#            1
# Name: book_language, dtype: int64

# %%
books_scrapped_cleaned.to_csv(file_scrapper_cleaned, sep = "|", index = False)

# %% [markdown]
# ## Awards
# Cleaning done in Colab (for rapitity matters !)

# %%
books_scrapped_cleaned = pd.read_csv(file_scrapper_cleaned, sep = '|')

# %%
stats_awa = books_scrapped_cleaned["awards"]
stats_awa.head()
# Out:
# 0                    NaN
# 1    Trillium Book Award
# 2                    NaN
# 3                    NaN
# 4                    NaN
# Name: awards, dtype: object

# %%
stats_awards = books_scrapped_cleaned["awards"].value_counts()
stats_awards[stats_awards.values > 100]
# Out:
# Dorothy Canfield Fisher Children's Book Award Nominee     428
# National Book Award Finalist for Fiction                  233
# Hugo Award Nominee for Best Novel                         210
# National Book Critics Circle Award Nominee for Fiction    156
# Books I Loved Best Yearly                                 138
# Locus Award Nominee for Best Fantasy Novel                135
# Booker Prize Nominee                                      132
# Los Angeles Times Book Prize Nominee for Fiction          124
# Hugo Award for Best Novel                                 120
# International Dublin Literary Award Nominee               112
# Name: awards, dtype: int64

# %%
books_scrapped_cleaned["awards"].value_counts()
# Out:
# Dorothy Canfield Fisher Children's Book Award Nominee                                       428
# National Book Award Finalist for Fiction                                                    233
# Hugo Award Nominee for Best Novel                                                           210
# National Book Critics Circle Award Nominee for Fiction                                      156
# Books I Loved Best Yearly                                                                   138
# Locus Award Nominee for Best Fantasy Novel                                                  135
# Booker Prize Nominee                                                                        132
# Los Angeles Times Book Prize Nominee for Fiction                                            124
# Hugo Award for Best Novel                                                                   120
# International Dublin Literary Award Nominee                                                 112
# Margaret A. Edwards Award                                                                    96
# Anthony Award Nominee for Best Novel                                                         93
# Nebula Award Nominee for Best Novel                                                          91
# National Book Critics Circle Award Nominee for General Nonfiction                            89
# Newbery Medal Nominee                                                                        77
# All About Romance                                                                            73
# Orange Prize Nominee for Fiction Longlist                                                    71
# World Fantasy Award Nominee for Best Novel                                                   70
# Newbery Medal                                                                                60
# Edgar Award Nominee for Best Novel                                                           60
# Lincoln Award Nominee                                                                        58
# Massachusetts Children's Book Award                                                          56
# Prometheus Hall of Fame Award                                                                54
# Dilys Award Nominee                                                                          54
# Locus Award Nominee for Best SF Novel                                                        54
# Zilveren Griffel                                                                             53
# Audie Award for Classic                                                                      52
# International Dublin Literary Award Nominee for Shortlist                                    50
# Anthony Award Nominee for Best First Novel                                                   47
# National Book Award for Fiction                                                              47
#                                                                                            ...
# HOLT Medallion by Virginia Romance Writers for Paranormal/Time Travel/Futuristic              1
# CWA International Dagger Nominee                                                              1
# Commonwealth Writers' Prize for Best Book Overall                                             1
# Prix Roger-Nimier                                                                             1
# James Beard Foundation Book Award Nominee for Writing on Food                                 1
# HOLT Medallion by Virginia Romance Writers Nominee for Paranormal/Time Travel/Futuristic      1
# Национална награда „Христо Г. Данов“ for Преводна художествена литература                     1
# Ethel Wilson Fiction Prize Nominee                                                            1
# National Book Award for Young People's Literature                                             1
# South Carolina Book Award for Young Adult Book Award                                          1
# Maryland Black-Eyed Susan Book Award for Grade 4-6                                            1
# Prix du Festival d'Angoulême for Prix du premier album                                        1
# Locus Award Nominee for Best Novella for "Anasazi"                                            1
# Mountains and Plains Booksellers Association Regional Book Award                              1
# Georgia Children's Book Award                                                                 1
# Anthony Award Nominee for Best Critical Work                                                  1
# Los Angeles Times Book Prize for Poetry                                                       1
# Victorian Premier's Literary Award for Vance Palmer Prize for Fiction                         1
# Golden Duck Award for Young Adult                                                             1
# Stonewall Book Award Nominee for Literature                                                   1
# Rudolf Koivu -palkinto                                                                        1
# RITA Award by Romance Writers of America Nominee for Long Contemporary Romance                1
# Prêmio Jabuti                                                                                 1
# New Mexico Land of Enchantment Award for Young Adult                                          1
# Seiun Award 星雲賞 Nominee for Best Japanese Novel                                               1
# World Fantasy Award for Best Collection                                                       1
# Premi de la Crítica Serra d'Or for novel·la                                                   1
# Bokhandlerprisen                                                                              1
# James Tait Black Memorial Prize                                                               1
# Locus Award Nominee for Best Anthology and Best Short Story for "The Edge of the World"       1
# Name: awards, Length: 613, dtype: int64

# %% [markdown]
# ## books_in_series

# %%
stats_ser = books_scrapped_cleaned.books_in_series[books_scrapped_cleaned.books_in_series != []]
stats_ser

# %%
len(stats_ser)
